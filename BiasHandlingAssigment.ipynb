# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Billionaires Statistics Dataset.csv')

# %%
df.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 0               France  ...                1.1   $2,715,518,274,227
# 1        United States  ...                7.5  $21,427,700,000,000
# 2        United States  ...                7.5  $21,427,700,000,000
# 3        United States  ...                7.5  $21,427,700,000,000
# 4        United States  ...                7.5  $21,427,700,000,000
#
#   gross_tertiary_education_enrollment  \
# 0                                65.6
# 1                                88.2
# 2                                88.2
# 3                                88.2
# 4                                88.2
#
#   gross_primary_education_enrollment_country life_expectancy_country  \
# 0                                      102.5                    82.5
# 1                                      101.8                    78.5
# 2                                      101.8                    78.5
# 3                                      101.8                    78.5
# 4                                      101.8                    78.5
#
#   tax_revenue_country_country total_tax_rate_country population_country  \
# 0                        24.2                   60.7         67059887.0
# 1                         9.6                   36.6        328239523.0
# 2                         9.6                   36.6        328239523.0
# 3                         9.6                   36.6        328239523.0
# 4                         9.6                   36.6        328239523.0
#
#   latitude_country longitude_country
# 0        46.227638          2.213749
# 1        37.090240        -95.712891
# 2        37.090240        -95.712891
# 3        37.090240        -95.712891
# 4        37.090240        -95.712891
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (2640, 35)

# %%
# Columns to be deleted
columns_to_delete = ['rank','personName','city','source','countryOfCitizenship','category','organization','selfMade','birthDate','lastName','firstName','title','date','state','residenceStateRegion','birthYear','birthMonth','birthDay','cpi_country','cpi_change_country','gdp_country','gross_tertiary_education_enrollment','gross_primary_education_enrollment_country','life_expectancy_country','tax_revenue_country_country','total_tax_rate_country','population_country','latitude_country','longitude_country']

# Deleting the specified columns
df.drop(columns=columns_to_delete, inplace=True)

# Display the modified DataFrame
print(df)
# Out:
#       finalWorth   age        country             industries status gender
# 0         211000  74.0         France       Fashion & Retail      U      M
# 1         180000  51.0  United States             Automotive      D      M
# 2         114000  59.0  United States             Technology      D      M
# 3         107000  78.0  United States             Technology      U      M
# 4         106000  92.0  United States  Finance & Investments      D      M
# ...          ...   ...            ...                    ...    ...    ...
# 2635        1000  51.0          China             Healthcare      D      M
# 2636        1000  80.0  United States        Food & Beverage      E      M
# 2637        1000  60.0          China          Manufacturing      R      M
# 2638        1000  71.0          China            Real Estate      D      M
# 2639        1000  66.0    Philippines            Diversified      R      M
#
# [2640 rows x 6 columns]

# %%
df.head()
# Out:
#    finalWorth   age        country             industries status gender
# 0      211000  74.0         France       Fashion & Retail      U      M
# 1      180000  51.0  United States             Automotive      D      M
# 2      114000  59.0  United States             Technology      D      M
# 3      107000  78.0  United States             Technology      U      M
# 4      106000  92.0  United States  Finance & Investments      D      M

# %%
df.shape
# Out:
# (2640, 6)

# %%
missingvalues=df.isnull().sum()
print(missingvalues)
# Out:
# finalWorth     0
# age           65
# country       38
# industries     0
# status         0
# gender         0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(), inplace= True)
df['country'].fillna(df['country'].mode()[0], inplace= True)

# %%
missingvalues=df.isnull().sum()
print(missingvalues)
# Out:
# finalWorth    0
# age           0
# country       0
# industries    0
# status        0
# gender        0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# For example, if you want to standardize columns 'A' and 'B':
columns_to_standardize = ['finalWorth','age','country', 'industries','status','gender']

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the selected columns
df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])
print(df)
# Out:
#       finalWorth       age   country  industries    status    gender
# 0       4.959596  0.694456 -0.886015   -0.881773  1.327401  0.382532
# 1       4.933544 -1.087239  1.093639   -1.727200 -0.905799  0.382532
# 2       4.907492 -0.493341  1.093639    1.654506 -0.905799  0.382532
# 3       4.881441  0.991406  1.093639    1.654506  1.327401  0.382532
# 4       4.855389  2.030728  1.093639   -0.670417 -0.905799  0.382532
# ...          ...       ...       ...         ...       ...       ...
# 2635   -0.719713 -1.087239 -1.202760   -0.036347 -0.905799  0.382532
# 2636   -0.719713  1.139880  1.093639   -0.459060 -0.459159  0.382532
# 2637   -0.719713 -0.419103 -1.202760    0.386366  0.434121  0.382532
# 2638   -0.719713  0.471744 -1.202760    1.020436 -0.905799  0.382532
# 2639   -0.719713  0.100558  0.262184   -1.304487  0.434121  0.382532
#
# [2640 rows x 6 columns]

# %%
df_cat=df.select_dtypes(np.object)
df_num=df.select_dtypes(np.number)
df_num

# %%
df_cat

# %%
# Get the data types of each column
data_types = df.dtypes

# Print the data types
print(data_types)
# Out:
# finalWorth      int64
# age           float64
# country        object
# industries     object
# status         object
# gender         object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode each categorical column
for column in ['finalWorth','age','country','industries', 'status','gender' ]:
    df[column] = label_encoder.fit_transform(df[column])
# Display the modified DataFrame
print(df)
# Out:
#       finalWorth  age  country  industries  status  gender
# 0            218   53       24           4       5       1
# 1            217   29       74           0       0       1
# 2            216   37       74          16       0       1
# 3            215   57       74          16       5       1
# 4            214   71       74           5       0       1
# ...          ...  ...      ...         ...     ...     ...
# 2635           0   29       16           8       0       1
# 2636           0   59       74           6       1       1
# 2637           0   38       16          10       3       1
# 2638           0   50       16          13       0       1
# 2639           0   45       53           2       3       1
#
# [2640 rows x 6 columns]

# %%
# Get the data types of each column
data_types = df.dtypes

# Print the data types
print(data_types)
# Out:
# finalWorth    int64
# age           int64
# country       int64
# industries    int64
# status        int64
# gender        int64
# dtype: object

# %%
# Create a box plot
plt.boxplot(df)

# Add title and labels
plt.title('Box Plot Example')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Show the plot
plt.show()

# %%
# Scatter plot
plt.scatter(df['age'], df['status'])  # Replace 'X-axis Column' and 'Y-axis Column' with your actual column names
plt.title('Scatter Plot Example')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %%
# Explore the age distribution
sns.histplot(df['age'], bins=20, kde=True)
plt.show()
# Calculate summary statistics
mean_age = df['age'].mean()
median_age = df['age'].median()
mode_age = df['age'].mode().values[0]

print(f"Mean age: {mean_age}, Median age: {median_age}, Mode age: {mode_age}")
# Out:
# Mean age: 43.64545454545455, Median age: 44.0, Mode age: 38

# %%
# Define a function to identify and remove outliers
def remove_outliers(df, threshold=1.0):
    q1 = np.percentile(df, 25)
    q3 = np.percentile(df, 75)
    iqr = q3 - q1
    lower_bound = q1 - threshold * iqr
    upper_bound = q3 + threshold * iqr

    return df[(df >= lower_bound) & (df <= upper_bound)]


# Remove outliers
cleaned_data = remove_outliers(df)

print("Original Data:", df)
print("Cleaned Data:", cleaned_data)
# Out:
# Original Data:       finalWorth  age  country  industries  status  gender
# 0            218   53       24           4       5       1
# 1            217   29       74           0       0       1
# 2            216   37       74          16       0       1
# 3            215   57       74          16       5       1
# 4            214   71       74           5       0       1
# ...          ...  ...      ...         ...     ...     ...
# 2635           0   29       16           8       0       1
# 2636           0   59       74           6       1       1
# 2637           0   38       16          10       3       1
# 2638           0   50       16          13       0       1
# 2639           0   45       53           2       3       1
#
# [2640 rows x 6 columns]
# Cleaned Data:       finalWorth   age  country  industries  status  gender
# 0            NaN  53.0     24.0           4       5       1
# 1            NaN  29.0      NaN           0       0       1
# 2            NaN  37.0      NaN          16       0       1
# 3            NaN  57.0      NaN          16       5       1
# 4            NaN   NaN      NaN           5       0       1
# ...          ...   ...      ...         ...     ...     ...
# 2635         0.0  29.0     16.0           8       0       1
# 2636         0.0  59.0      NaN           6       1       1
# 2637         0.0  38.0     16.0          10       3       1
# 2638         0.0  50.0     16.0          13       0       1
# 2639         0.0  45.0     53.0           2       3       1
#
# [2640 rows x 6 columns]

# %%
cleaned_data.head()
# Out:
#    finalWorth   age  country  industries  status  gender
# 0         NaN  53.0     24.0           4       5       1
# 1         NaN  29.0      NaN           0       0       1
# 2         NaN  37.0      NaN          16       0       1
# 3         NaN  57.0      NaN          16       5       1
# 4         NaN   NaN      NaN           5       0       1

# %%
# Create a box plot
plt.boxplot(cleaned_data)

# Add title and labels
plt.title('Box Plot Example')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

# Show the plot
plt.show()

# %%
# Scatter plot
plt.scatter(df['age'], df['status'])  # Replace 'X-axis Column' and 'Y-axis Column' with your actual column names
plt.title('Scatter Plot Example')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %%
# Explore the age distribution
sns.histplot(df['age'], bins=20, kde=True)
plt.show()
# Calculate summary statistics
mean_age = df['age'].mean()
median_age = df['age'].median()
mode_age = df['age'].mode().values[0]

print(f"Mean age: {mean_age}, Median age: {median_age}, Mode age: {mode_age}")
# Out:
# Mean age: 43.64545454545455, Median age: 44.0, Mode age: 38

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    df[['age']],  # Use only the 'age' column
    df['age'],
    test_size=0.2,
    random_state=42
)

# Train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
#y_pred

# %%
# Calculate the Mean Squared Error (MSE) on the test set
mse = mean_squared_error(y_test, y_pred)
print(f'\nMean Squared Error: {mse}')
# Out:
# Mean Squared Error: 2.6313292164303904e-29

# %%
# Plot the regression line
plt.scatter(X_test, y_test, color='black', label='True values')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Regression line')
plt.title('Linear Regression: Age vs Age')
plt.xlabel('Age')
plt.ylabel('Age')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')

# Calculate R-squared
r_squared = r2_score(y_test, y_pred)
print(f'R-squared: {r_squared}')
# Out:
# Mean Absolute Error: 3.0648884104045988e-15
# R-squared: 1.0
